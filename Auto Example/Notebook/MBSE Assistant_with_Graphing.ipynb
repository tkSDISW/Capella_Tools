# %% [markdown]
# # Model Based System Engineering Assistant:
# ## Leveraging AI for System Engineering models
#
# Welcome to the **MBSE Assistant Notebook**, a powerful tool designed to augment your ability to review, comprehend, and enhance system models with AI-driven support. This notebook integrates a variety of capabilities to assist with:
#
# 1. **Model Review and Comprehension**:
#    - Gain deeper insights into the structure and behavior of your system model.
#    - Use AI to clarify relationships, dependencies, and interactions within the model.
#
# 2. **Impact Analysis**:
#    - Explore the potential effects of component failures on the system.
#    - Simulate scenarios to identify vulnerabilities and design improvements.
#
# 3. **Simulation Generation**:
#    - Automatically generate simulations based on the model's architecture and behaviors.
#    - Use simulations for validation, testing, and demonstration purposes.
#
# 4. **Failure Analysis**:
#    - Assess the system's resilience under various failure conditions.
#    - Extract meaningful insights to strengthen reliability and performance.
#
# 5. **Content Extraction for Downstream Domains**:
#    - Convert model data into formats suitable for use in other engineering domains.
#    - Facilitate seamless collaboration across teams and tools.
#
# This notebook serves as a comprehensive platform to bridge the gap between system models and actionable insights, empowering architects to make informed decisions and design robust solutions. Whether you're investigating enhancements, running failure simulations, or preparing data for external domains, this assistant streamlines the process with AI-enhanced guidance.
#
# Feel free to explore and adapt the prompts and models to suit your specific use case. Let’s dive in and unlock the potential of your system model!

# %% [markdown]
# ### Model-Specific Code (Do Not Modify)
#
# This section contains code that is specific to the system model. It is updated only when the model is changed and should not require user modifications under normal circumstances.
#
# If a new model is introduced, ensure this section is reviewed and updated as needed.

# %%
#!pip install --upgrade git+https://github.com/tkSDISW/Capella_Tools 
import capellambse.decl
from capella_tools import Pub4C
from capella_tools import capellambse_helper

from IPython import display as diag_display
resources = {
    "eRod_A_V_202406": "eRod_A_V_202406/eRod_A_V_202406",
}
path_to_model = "../eRod_A_V_202406.aird"
model = capellambse.MelodyModel(path_to_model, resources=resources)
# Instantiate the class with the traceability file
traceability_store = Pub4C.Traceability_Store("../eRod_A_V_202406.traceability")
# Out:
# Ignoring file of unknown type, loaded model may be incomplete: eRod_Autonomous_Vehicle_202406.traceability
# Ignoring file of unknown type, loaded model may be incomplete: eRod_A_V_202406.traceability

# %% [markdown]
# ## 🔄 Embedding Generation Process
#
# ### Overview
# This section generates embeddings, which streamlines processing and analyzing the model. The embeddings provide a structured representation of the data that powers subsequent tasks and visualizations.
#
# ### When is this step necessary?
# - **Initial Run:** If this notebook is being run for the first time, embeddings will need to be generated.
# - **Model Updates:** If the underlying model has been modified, regenerating embeddings ensures the data remains accurate and up-to-date.
#
# ### Important Notes
# - **Duration:** This process may take **a minute or more** to complete, depending on the size and complexity of the model.
# - **Output:** Upon completion, embeddings will be ready for use in subsequent sections of the notebook.
#
# ### Instructions
# 1. Ensure the required model is loaded.
# 2. Run the cell below to initiate the embedding generation process.
# 3. Wait for the process to complete before proceeding.
#
# > 💡 **Tip:** You can monitor progress in the notebook's output cell. If any errors occur, check that the model is properly configured and accessible.
#
# ---
#
# > ⚠️ **Warning:** Interrupting this step may result in incomplete or invalid embeddings. If interrupted, re-run the cell to restart the process.
#
# ---
#
# Continue to the next cell to generate embeddings. 🚀

# %%
from capella_tools  import capella_embeddings_manager

# Generate embeddings for all objects
model_embedding_manager = capella_embeddings_manager.EmbeddingManager()

embedding_file = "embeddings.json" 
model_embedding_manager.set_files( path_to_model , embedding_file)

model_embedding_manager.create_model_embeddings(model)
# Out:
# OpenAI API Key retrieved successfully.
# Loading embeddings
# embeddings loaded.

# %% [markdown]
# ## 🎯 Prompt for System Model Element Analysis
#
# ### Purpose
# This cell accepts a prompt to identify and isolate the specific object(s) to be analyzed. Providing detailed and accurate information in the prompt will ensure the best performance during the analysis.
#
# ### What to Include in Your Prompt
# For optimal results, specify the following details about the object(s):
# 1. **Type of ARCADIA Object:** Clearly state the type of the object (e.g., Logical Component, Physical Component, Functional Exchange).
# 2. **Name of the Object:** Provide the exact name of the object as defined in the model.
# 3. **ARCADIA Phase:** Specify the phase associated with the object (e.g., Operational Analysis, System Analysis, Logical Architecture, Physical Architecture).
# 4. **Related Objects:** Identify any objects connected via exchanges or dependencies.
#
# ### Example Prompt
# Locate the Logical Component named Brake Pedal in the Logical phase and has a Driver supplying input.
# ### ✅ Tips for Success
# - **Use precise terminology:** Ensure your prompt aligns with the model's structure and terminology.
# - **Include related objects:** Whenever possible, specify related objects to enhance context and improve analysis accuracy.
# - **Double-check details:** Verify object names and phases to ensure they match the model exactly.
# '''
#
# ### 🚀 Next Steps
# 1. Run the cell below.
# 2. Enter your prompt, providing the necessary details as outlined above.
# 3. Wait for the analysis to complete.
# 4. Select the best index or indexes for analysis. (The last selection will drive selection of a prompt.)
#
# > 💡 **Tip:** If you're unsure about the model structure, review the documentation or refer to the model's diagrams for additional guidance.

# %%
#selected_objects  = model_embedding_manager.interactive_query_and_selection()

from jupyter_ui_poll import ui_events
import time

# Start interactive selection
model_embedding_manager.interactive_query_and_selection_widgets()


# Retrieve the selection after submission
selected_objects = model_embedding_manager.get_selected_objects()
# Out:
# VBox(children=(Text(value='', layout=Layout(width='80%'), placeholder='Enter query for objects...'), SelectMul…
# Waiting for selection...

# %% [markdown]
# ## 📝 Generate Structured Input File
#
# ### Purpose
# This cell generates a structured structured input file, `capella_model.yaml`, which serves as input for prompts tailored to the object type of the last selected item. This ensures that the prompt aligns with the model's structure and provides accurate context for analysis.
#
# ### What This Cell Does
# - Extracts data related to the elements selected.
# - Structures the data into a YAML format.
# - Saves the YAML file as `capella_model.yaml` for further use.
#
# ### Key Features
# - The YAML file includes:
#   - **Object Type:** The type of the element.
#   - **Object Details:** Attributes, relationships, and associated exchanges.
#   - **Structured Input:** Designed to enhance prompt accuracy and model analysis.
#
# ### Instructions
# 1. Run this cell to create the `capella_model.yaml` file.
# 2. Ensure the last selected item is correctly identified to avoid mismatched data.
# 3. Use the generated YAML file as structured input for tailored prompts in subsequent steps.
#
# ### Notes
# - The file will be saved in the current working directory.
# - If the selected object changes, re-run this cell to update the YAML file.
#
# > 💡 **Tip:** Review the contents of `capella_model.yaml` if needed to ensure accuracy and completeness.

# %%
#Workflow
from capella_tools import capellambse_yaml_manager

yaml_handler = capellambse_yaml_manager.CapellaYAMLHandler()
   
#Generate YAML for the logical component and append to the file
for object in  selected_objects : 
    yaml_handler.generate_yaml(model.by_uuid(object["uuid"]))  
    


yaml_handler.generate_traceability_related_objects(model,traceability_store)

#yaml_handler.display()
yaml_handler.generate_yaml_referenced_objects()
#yaml_handler.display()

yaml_handler.write_output_file()

# %% [markdown]
# ## 🖼️ Generate Contextual Diagram
#
# ### Purpose
# This cell generates a **contextual diagram** for the selected object. The diagram visually represents the object's relationships and interactions, providing a clear and comprehensive view of its context within the model.
#
# ### Supported Object Types
# This functionality works the following ARCADIA elements, including:
# - **Functions**
# - **Activities**
# - **Components**
# - **Entities**
# - **Exchanges and Interactions**
# - **Physical Links**
#
# ### What This Cell Does
# - Identifies the selected object.
# - Extracts relevant relationships, exchanges, and dependencies.
# - Creates a contextual diagram based on the object's type and its connections.
#
# ### Instructions
# 1. Ensure the object is correctly selected in the previous step.
# 2. Run this cell to generate the contextual diagram.
# 3. Review the output to verify accuracy and completeness.
#
# ### Key Benefits
# - **Clarity:** Visualizes how the selected object interacts with other model elements.
# - **Versatility:** Works seamlessly across ARCADIA functions, activities, components, and entities.
# - **Actionable Insight:** Helps identify key dependencies and relationships for analysis.
#
# ### Notes
# - The diagram will be displayed below upon completion.
# - If the selected object changes, re-run this cell to update the contextual

# %%
for object in  selected_objects : 
    #print(object)
    if object["type"] == "Diagram" :
        diagram = model.by_uuid(object["uuid"])
        #display(diagram)
    else:
        obj = model.by_uuid(object["uuid"])
        capellambse_helper.display_context_diagram(obj)
# Out:
# The object:Manual Braking cannot be displayed in a Context Diagram.

# %% [markdown]
# ## 🖼️ Graph Analysis
#
# ### Purpose
# This cell generates a **graph** for the yaml file. The graph visually represents the object's relationships and interactions, providing a clear and comprehensive view of its context within the model.
#
# ### Graph Content
# The graph is gnerated by a prompt.
# Analyze the YAML content and extract relationships suitable for a graph.
# - Each relationship should be a tuple: (source, target, label).
# - Use simple labels like 'causes', 'enables', 'requires', 'inhibits'.
# - Output ONLY a Python list of these tuples.
# - No explanation, no extra text, just the list in Python syntax.
#
# ### Graph Format
# Generate a directed graph based on given relations.
#
# ### Instructions
# Call the method with folowing syntax.
#
# ### Key Benefits
# - **Clarity:** Visualizes how the selected object interacts with other model elements.
# - **Versatility:** Works seamlessly across ARCADIA functions, activities, components, and entities.
# - **Actionable Insight:** Helps identify key dependencies and relationships for analysis.
#
# ### Notes
# - The diagram will be displayed below upon completion.
# - If the selected object changes, re-run this cell to update the contextual

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown, IFrame
from capella_tools  import Open_AI_RAG_manager


#print(object)
# Step 1: Get YAML content
yaml_content = yaml_handler.get_yaml_content()

# Step 2: Invoke ChatGPT for analysis
analyzer = Open_AI_RAG_manager.ChatGPTAnalyzer(yaml_content)

analyzer.analyze_and_generate_graph()


# Show inside the notebook
IFrame(src="graph.html", width="100%", height="750px")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Chat session ended. Moving to the next cell.
# OpenAI API Key retrieved successfully.
# Sending prompt to extract graphable relations...
# Relations Text: ```html
# [
#     ("Manual Braking", "Apply Brake", "involves"),
#     ("Manual Braking", "Deliver traction to surface", "involves"),
#     ("Manual Braking", "Brake", "involves"),
#     ("Manual Braking", "Converts mechanical to hydaulic", "involves"),
#     ("Manual Braking", "Distribute force", "involves"),
#     ("Manual Braking", "Reduce Skid", "involves"),
#     ("Manual Braking", "Amplify force", "involves"),
#     ("Manual Braking", "Provide Friction", "involves"),
#     ("Manual Braking", "Deliver traction to surface", "involves"),
#     ("Manual Braking", "Deliver traction to surface", "involves"),
#     ("Manual Braking", "Deliver traction to surface", "involves"),
#     ("Manual Braking", "Brake Force", "involves"),
#     ("Manual Braking", "Traction 1", "involves"),
#     ("Manual Braking", "Brake force", "involves"),
#     ("Manual Braking", "Modulate Brake", "involves"),
#     ("Manual Braking", "High Pressure", "involves"),
#     ("Manual Braking", "Low Pressure", "involves"),
#     ("Manual Braking", "Pad Force 1", "involves"),
#     ("Manual Braking", "Brake 1", "involves"),
#     ("Manual Braking", "Pade Force 2", "involves"),
#     ("Manual Braking", "Pad Force 4", "involves"),
#     ("Manual Braking", "Pad Force 3", "involves"),
#     ("Manual Braking", "Brake 2", "involves"),
#     ("Manual Braking", "Brake 4", "involves"),
#     ("Manual Braking", "Brake 3", "involves"),
#     ("Manual Braking", "Traction 2", "involves"),
#     ("Manual Braking", "Traction 3", "involves"),
#     ("Manual Braking", "Traction 3", "involves"),
#     ("Apply Brake", "Driver", "allocated to"),
#     ("Apply Brake", "FIP 1", "port"),
#     ("Apply Brake", "FOP 1", "port"),
#     ("FIP 1", "Slow Vehicle", "exchanges"),
#     ("Slow Vehicle", "Drive vehicle", "source"),
#     ("Slow Vehicle", "Apply Brake", "target"),
#     ("FOP 1", "Brake Force", "exchanges"),
#     ("Brake Force", "Apply Brake", "source"),
#     ("Brake Force", "Brake", "target"),
#     ("Deliver traction to surface", "Wheel", "allocated to"),
#     ("Deliver traction to surface", "Axle Torque In", "port"),
#     ("Deliver traction to surface", "Brake In", "port"),
#     ("Axle Torque In", "Deceleration", "exchanges"),
#     ("Deceleration", "Slow down and stop the vehicle", "source"),
#     ("Deceleration", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Brake 1", "exchanges"),
#     ("Brake 1", "Slow Wheels", "source"),
#     ("Brake 1", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Wheel Out", "port"),
#     ("Wheel Out", "Traction 1", "exchanges"),
#     ("Traction 1", "Deliver traction to surface", "source"),
#     ("Traction 1", "Provide Friction", "target"),
#     ("Brake", "Brake pedal", "allocated to"),
#     ("Brake", "FIP 1", "port"),
#     ("Brake FIP 1", "Brake Force", "exchanges"),
#     ("Brake Force", "Apply Brake", "source"),
#     ("Brake Force", "Brake", "target"),
#     ("Brake", "FOP 1", "port"),
#     ("Brake FOP 1", "Brake force", "exchanges"),
#     ("Brake force", "Brake", "source"),
#     ("Brake force", "Converts mechanical to hydaulic", "target"),
#     ("Brake", "FOP 2", "port"),
#     ("Brake FOP 2", "Brake force", "exchanges"),
#     ("Brake force", "Brake", "source"),
#     ("Brake force", "Measure brake force", "target"),
#     ("Brake", "FOP 1", "port"),
#     ("Brake FOP 1", "Brake Level", "exchanges"),
#     ("Brake Level", "Brake", "source"),
#     ("Brake Level", "Decelerate Vehicle", "target"),
#     ("Converts mechanical to hydaulic", "Brake Master Cylinder", "allocated to"),
#     ("Converts mechanical to hydaulic", "FIP 1", "port"),
#     ("Converts mechanical to hydaulic FIP 1", "Brake force", "exchanges"),
#     ("Brake force", "Brake", "source"),
#     ("Brake force", "Converts mechanical to hydaulic", "target"),
#     ("Converts mechanical to hydaulic", "Hydraulic Low Press", "port"),
#     ("Hydraulic Low Press", "Low Pressure", "exchanges"),
#     ("Low Pressure", "Converts mechanical to hydaulic", "source"),
#     ("Low Pressure", "Amplify force", "target"),
#     ("Distribute force", "Brake Lines and Fluid", "allocated to"),
#     ("Distribute force", "FIP 1", "port"),
#     ("Distribute force FIP 1", "High Pressure", "exchanges"),
#     ("High Pressure", "Amplify force", "source"),
#     ("High Pressure", "Distribute force", "target"),
#     ("Distribute force", "FOP 1", "port"),
#     ("Distribute force FOP 1", "Pade Force 2", "exchanges"),
#     ("Pade Force 2", "Distribute force", "source"),
#     ("Pade Force 2", "Force to Pads", "target"),
#     ("Distribute force FOP 1", "Pad Force 3", "exchanges"),
#     ("Pad Force 3", "Distribute force", "source"),
#     ("Pad Force 3", "Force to Pads", "target"),
#     ("Distribute force FOP 1", "Pad Force 4", "exchanges"),
#     ("Pad Force 4", "Distribute force", "source"),
#     ("Pad Force 4", "Force to Pads", "target"),
#     ("Distribute force FOP 1", "Pad Force 1", "exchanges"),
#     ("Pad Force 1", "Distribute force", "source"),
#     ("Pad Force 1", "Force to Pads", "target"),
#     ("Reduce Skid", "ABS Controller", "allocated to"),
#     ("Reduce Skid", "FIP 1", "port"),
#     ("Reduce Skid FIP 1", "Wheel Speed", "exchanges"),
#     ("Wheel Speed", "Measure wheel rotation speed", "source"),
#     ("Wheel Speed", "Reduce Skid", "target"),
#     ("Reduce Skid", "FOP 1", "port"),
#     ("Reduce Skid FOP 1", "Modulate Brake", "exchanges"),
#     ("Modulate Brake", "Reduce Skid", "source"),
#     ("Modulate Brake", "Amplify force", "target"),
#     ("Reduce Skid", "FOP 1", "port"),
#     ("Reduce Skid FOP 1", "ABS Controller", "exchanges"),
#     ("ABS Controller", "Reduce Skid", "source"),
#     ("ABS Controller", "Relay Messages", "target"),
#     ("Amplify force", "Hydraulic Control Modulator", "allocated to"),
#     ("Amplify force", "FIP 1", "port"),
#     ("Amplify force FIP 1", "Electrical Energy", "exchanges"),
#     ("Electrical Energy", "Provide electrical energy", "source"),
#     ("Electrical Energy", "Amplify force", "target"),
#     ("Amplify force", "FIP 2", "port"),
#     ("Amplify force FIP 2", "Low Pressure", "exchanges"),
#     ("Low Pressure", "Converts mechanical to hydaulic", "source"),
#     ("Low Pressure", "Amplify force", "target"),
#     ("Amplify force", "FIP 1", "port"),
#     ("Amplify force FIP 1", "Modulate Brake", "exchanges"),
#     ("Modulate Brake", "Reduce Skid", "source"),
#     ("Modulate Brake", "Amplify force", "target"),
#     ("Amplify force", "FOP 1", "port"),
#     ("Amplify force FOP 1", "High Pressure", "exchanges"),
#     ("High Pressure", "Amplify force", "source"),
#     ("High Pressure", "Distribute force", "target"),
#     ("Provide Friction", "Terrain/Roads", "allocated to"),
#     ("Provide Friction", "FIP 1", "port"),
#     ("Provide Friction FIP 1", "Wheel Angles Wheel Forces", "exchanges"),
#     ("Wheel Angles Wheel Forces", "Steer Wheels", "source"),
#     ("Wheel Angles Wheel Forces", "Provide Friction", "target"),
#     ("Provide Friction", "FIP 2", "port"),
#     ("Provide Friction FIP 2", "Terrain", "exchanges"),
#     ("Terrain", "Provide diverse terrain", "source"),
#     ("Terrain", "Provide Friction", "target"),
#     ("Provide Friction", "inTraction", "port"),
#     ("Provide Friction inTraction", "Traction 1", "exchanges"),
#     ("Traction 1", "Deliver traction to surface", "source"),
#     ("Traction 1", "Provide Friction", "target"),
#     ("Provide Friction inTraction", "Traction 2", "exchanges"),
#     ("Traction 2", "Deliver traction to surface", "source"),
#     ("Traction 2", "Provide Friction", "target"),
#     ("Provide Friction inTraction", "Traction 3", "exchanges"),
#     ("Traction 3", "Deliver traction to surface", "source"),
#     ("Traction 3", "Provide Friction", "target"),
#     ("Provide Friction inTraction", "Traction 3", "exchanges"),
#     ("Traction 3", "Deliver traction to surface", "source"),
#     ("Traction 3", "Provide Friction", "target"),
#     ("Deliver traction to surface", "Wheel", "allocated to"),
#     ("Deliver traction to surface", "Axle Torque In", "port"),
#     ("Deliver traction to surface", "Brake In", "port"),
#     ("Deliver traction to surface Brake In", "Brake 2", "exchanges"),
#     ("Brake 2", "Slow Wheels", "source"),
#     ("Brake 2", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Wheel Out", "port"),
#     ("Deliver traction to surface Wheel Out", "Traction 2", "exchanges"),
#     ("Traction 2", "Deliver traction to surface", "source"),
#     ("Traction 2", "Provide Friction", "target"),
#     ("Deliver traction to surface", "Wheel", "allocated to"),
#     ("Deliver traction to surface", "Axle Torque In", "port"),
#     ("Deliver traction to surface", "Brake In", "port"),
#     ("Deliver traction to surface Brake In", "Brake 4", "exchanges"),
#     ("Brake 4", "Slow Wheels", "source"),
#     ("Brake 4", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Wheel Out", "port"),
#     ("Deliver traction to surface Wheel Out", "Traction 3", "exchanges"),
#     ("Traction 3", "Deliver traction to surface", "source"),
#     ("Traction 3", "Provide Friction", "target"),
#     ("Deliver traction to surface", "Wheel", "allocated to"),
#     ("Deliver traction to surface", "Axle Torque In", "port"),
#     ("Deliver traction to surface", "Brake In", "port"),
#     ("Deliver traction to surface Brake In", "Brake 3", "exchanges"),
#     ("Brake 3", "Slow Wheels", "source"),
#     ("Brake 3", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Wheel Out", "port"),
#     ("Deliver traction to surface Wheel Out", "Traction 3", "exchanges"),
#     ("Traction 3", "Deliver traction to surface", "source"),
#     ("Traction 3", "Provide Friction", "target"),
#     ("Braking Torque", "Brake 1", "linked model element"),
#     ("Pedal Force Feedback", "Brake Force", "linked model element"),
#     ("Driver", "Drive on a race track", "components"),
#     ("Driver", "Car racing experience absorbed", "components"),
#     ("Driver", "Report issues", "components"),
#     ("Driver", "Get informed with issues", "components"),
#     ("Driver", "Get Software-update", "components"),
#     ("Driver", "Obtain car racing experience", "components"),
#     ("Driver", "Drive vehicle", "components"),
#     ("Driver", "Recieve feedback", "components"),
#     ("Driver", "Provide solution", "components"),
#     ("Driver", "Apply Brake", "components"),
#     ("Driver", "CP 1", "port"),
#     ("CP 1", "Information", "exchanges"),
#     ("Information", "Driver", "source"),
#     ("Information", "eRod System", "target"),
#     ("Driver", "CP 2", "port"),
#     ("CP 2", "Experience", "exchanges"),
#     ("Experience", "eRod System", "source"),
#     ("Experience", "Driver", "target"),
#     ("Driver", "CP 3", "port"),
#     ("CP 3", "T", "exchanges"),
#     ("T", "Driver", "source"),
#     ("T", "Brake pedal", "target"),
#     ("T", "Brake Force", "allocated functional exchanges"),
#     ("Apply Brake", "Driver", "allocated to"),
#     ("Apply Brake", "FIP 1", "port"),
#     ("FIP 1", "Slow Vehicle", "exchanges"),
#     ("Slow Vehicle", "Drive vehicle", "source"),
#     ("Slow Vehicle", "Apply Brake", "target"),
#     ("Apply Brake", "FOP 1", "port"),
#     ("FOP 1", "Brake Force", "exchanges"),
#     ("Brake Force", "Apply Brake", "source"),
#     ("Brake Force", "Brake", "target"),
#     ("Deliver traction to surface", "Wheel", "allocated to"),
#     ("Deliver traction to surface", "Axle Torque In", "port"),
#     ("Axle Torque In", "Deceleration", "exchanges"),
#     ("Deceleration", "Slow down and stop the vehicle", "source"),
#     ("Deceleration", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Brake In", "port"),
#     ("Brake In", "Brake 1", "exchanges"),
#     ("Brake 1", "Slow Wheels", "source"),
#     ("Brake 1", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Wheel Out", "port"),
#     ("Wheel Out", "Traction 1", "exchanges"),
#     ("Traction 1", "Deliver traction to surface", "source"),
#     ("Traction 1", "Provide Friction", "target"),
#     ("Brake", "Brake pedal", "allocated to"),
#     ("Brake", "FIP 1", "port"),
#     ("FIP 1", "Brake Force", "exchanges"),
#     ("Brake Force", "Apply Brake", "source"),
#     ("Brake Force", "Brake", "target"),
#     ("Brake", "FOP 1", "port"),
#     ("FOP 1", "Brake force", "exchanges"),
#     ("Brake force", "Brake", "source"),
#     ("Brake force", "Converts mechanical to hydaulic", "target"),
#     ("Brake", "FOP 2", "port"),
#     ("FOP 2", "Brake force", "exchanges"),
#     ("Brake force", "Brake", "source"),
#     ("Brake force", "Measure brake force", "target"),
#     ("Brake", "FOP 1", "port"),
#     ("FOP 1", "Brake Level", "exchanges"),
#     ("Brake Level", "Brake", "source"),
#     ("Brake Level", "Decelerate Vehicle", "target"),
#     ("Converts mechanical to hydaulic", "Brake Master Cylinder", "allocated to"),
#     ("Converts mechanical to hydaulic", "FIP 1", "port"),
#     ("FIP 1", "Brake force", "exchanges"),
#     ("Brake force", "Brake", "source"),
#     ("Brake force", "Converts mechanical to hydaulic", "target"),
#     ("Converts mechanical to hydaulic", "Hydraulic Low Press", "port"),
#     ("Hydraulic Low Press", "Low Pressure", "exchanges"),
#     ("Low Pressure", "Converts mechanical to hydaulic", "source"),
#     ("Low Pressure", "Amplify force", "target"),
#     ("Distribute force", "Brake Lines and Fluid", "allocated to"),
#     ("Distribute force", "FIP 1", "port"),
#     ("FIP 1", "High Pressure", "exchanges"),
#     ("High Pressure", "Amplify force", "source"),
#     ("High Pressure", "Distribute force", "target"),
#     ("Distribute force", "FOP 1", "port"),
#     ("FOP 1", "Pade Force 2", "exchanges"),
#     ("Pade Force 2", "Distribute force", "source"),
#     ("Pade Force 2", "Force to Pads", "target"),
#     ("FOP 1", "Pad Force 3", "exchanges"),
#     ("Pad Force 3", "Distribute force", "source"),
#     ("Pad Force 3", "Force to Pads", "target"),
#     ("FOP 1", "Pad Force 4", "exchanges"),
#     ("Pad Force 4", "Distribute force", "source"),
#     ("Pad Force 4", "Force to Pads", "target"),
#     ("FOP 1", "Pad Force 1", "exchanges"),
#     ("Pad Force 1", "Distribute force", "source"),
#     ("Pad Force 1", "Force to Pads", "target"),
#     ("Reduce Skid", "ABS Controller", "allocated to"),
#     ("Reduce Skid", "FIP 1", "port"),
#     ("FIP 1", "Wheel Speed", "exchanges"),
#     ("Wheel Speed", "Measure wheel rotation speed", "source"),
#     ("Wheel Speed", "Reduce Skid", "target"),
#     ("Reduce Skid", "FOP 1", "port"),
#     ("FOP 1", "Modulate Brake", "exchanges"),
#     ("Modulate Brake", "Reduce Skid", "source"),
#     ("Modulate Brake", "Amplify force", "target"),
#     ("Reduce Skid", "FOP 1", "port"),
#     ("FOP 1", "ABS Controller", "exchanges"),
#     ("ABS Controller", "Reduce Skid", "source"),
#     ("ABS Controller", "Relay Messages", "target"),
#     ("Amplify force", "Hydraulic Control Modulator", "allocated to"),
#     ("Amplify force", "FIP 1", "port"),
#     ("FIP 1", "Electrical Energy", "exchanges"),
#     ("Electrical Energy", "Provide electrical energy", "source"),
#     ("Electrical Energy", "Amplify force", "target"),
#     ("Amplify force", "FIP 2", "port"),
#     ("FIP 2", "Low Pressure", "exchanges"),
#     ("Low Pressure", "Converts mechanical to hydaulic", "source"),
#     ("Low Pressure", "Amplify force", "target"),
#     ("Amplify force", "FIP 1", "port"),
#     ("FIP 1", "Modulate Brake", "exchanges"),
#     ("Modulate Brake", "Reduce Skid", "source"),
#     ("Modulate Brake", "Amplify force", "target"),
#     ("Amplify force", "FOP 1", "port"),
#     ("FOP 1", "High Pressure", "exchanges"),
#     ("High Pressure", "Amplify force", "source"),
#     ("High Pressure", "Distribute force", "target"),
#     ("Provide Friction", "Terrain/Roads", "allocated to"),
#     ("Provide Friction", "FIP 1", "port"),
#     ("FIP 1", "Wheel Angles Wheel Forces", "exchanges"),
#     ("Wheel Angles Wheel Forces", "Steer Wheels", "source"),
#     ("Wheel Angles Wheel Forces", "Provide Friction", "target"),
#     ("Provide Friction", "FIP 2", "port"),
#     ("FIP 2", "Terrain", "exchanges"),
#     ("Terrain", "Provide diverse terrain", "source"),
#     ("Terrain", "Provide Friction", "target"),
#     ("Provide Friction", "inTraction", "port"),
#     ("inTraction", "Traction 1", "exchanges"),
#     ("Traction 1", "Deliver traction to surface", "source"),
#     ("Traction 1", "Provide Friction", "target"),
#     ("inTraction", "Traction 2", "exchanges"),
#     ("Traction 2", "Deliver traction to surface", "source"),
#     ("Traction 2", "Provide Friction", "target"),
#     ("inTraction", "Traction 3", "exchanges"),
#     ("Traction 3", "Deliver traction to surface", "source"),
#     ("Traction 3", "Provide Friction", "target"),
#     ("inTraction", "Traction 3", "exchanges"),
#     ("Traction 3", "Deliver traction to surface", "source"),
#     ("Traction 3", "Provide Friction", "target"),
#     ("Deliver traction to surface", "Wheel", "allocated to"),
#     ("Deliver traction to surface", "Axle Torque In", "port"),
#     ("Deliver traction to surface", "Brake In", "port"),
#     ("Brake In", "Brake 2", "exchanges"),
#     ("Brake 2", "Slow Wheels", "source"),
#     ("Brake 2", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Wheel Out", "port"),
#     ("Wheel Out", "Traction 2", "exchanges"),
#     ("Traction 2", "Deliver traction to surface", "source"),
#     ("Traction 2", "Provide Friction", "target"),
#     ("Deliver traction to surface", "Wheel", "allocated to"),
#     ("Deliver traction to surface", "Axle Torque In", "port"),
#     ("Deliver traction to surface", "Brake In", "port"),
#     ("Brake In", "Brake 4", "exchanges"),
#     ("Brake 4", "Slow Wheels", "source"),
#     ("Brake 4", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Wheel Out", "port"),
#     ("Wheel Out", "Traction 3", "exchanges"),
#     ("Traction 3", "Deliver traction to surface", "source"),
#     ("Traction 3", "Provide Friction", "target"),
#     ("Deliver traction to surface", "Wheel", "allocated to"),
#     ("Deliver traction to surface", "Axle Torque In", "port"),
#     ("Deliver traction to surface", "Brake In", "port"),
#     ("Brake In", "Brake 3", "exchanges"),
#     ("Brake 3", "Slow Wheels", "source"),
#     ("Brake 3", "Deliver traction to surface", "target"),
#     ("Deliver traction to surface", "Wheel Out", "port"),
#     ("Wheel Out", "Traction 3", "exchanges"),
#     ("Traction 3", "Deliver traction to surface", "source"),
#     ("Traction 3", "Provide Friction", "target"),
#     ("Drive on a race track", "Driver", "allocated to"),
#     ("Drive on a race track", "FOP 1", "port"),
#     ("FOP 1", "Command", "exchanges"),
#     ("Command", "Drive on a race track", "source"),
#     ("Command", "Motor Start", "target"),
#     ("Car racing experience absorbed", "Driver", "allocated to"),
#     ("Car racing experience absorbed", "inProvide", "port"),
#     ("inProvide", "Cause", "exchanges"),
#     ("Cause", "Stop", "source"),
#     ("Cause", "Car racing experience absorbed", "target"),
#     ("Report issues", "Driver", "allocated to"),
#     ("Report issues", "FIP 1", "port"),
#     ("FIP 1", "action", "exchanges"),
#     ("action", "Get informed with issues", "source"),
#     ("action", "Report issues", "target"),
#     ("Report issues", "FOP 1", "port"),
#     ("FOP 1", "Information", "exchanges"),
#     ("Information", "Report issues", "source"),
#     ("Information", "Software update", "target"),
#     ("FOP 1", "Information", "exchanges"),
#     ("Information", "Report issues", "source"),
#     ("Information", "Recieve feedback", "target"),
#     ("Get informed with issues", "Driver", "allocated to"),
#     ("Get informed with issues", "inDisplay", "port"),
#     ("inDisplay", "Display", "exchanges"),
#     ("Display", "Motor overheating warning", "source"),
#     ("Display", "Get informed with issues", "target"),
#     ("Get informed with issues", "FOP 1", "port"),
#     ("FOP 1", "action", "exchanges"),
#     ("action", "Get informed with issues", "source"),
#     ("action", "Report issues", "target"),
#     ("Get Software-update", "Driver", "allocated to"),
#     ("Get Software-update", "FIP 1", "port"),
#     ("FIP 1", "provide", "exchanges"),
#     ("provide", "Provide solution", "source"),
#     ("provide", "Get Software-update", "target"),
#     ("Get Software-update", "FOP 1", "port"),
#     ("FOP 1", "enable", "exchanges"),
#     ("enable", "Get Software-update", "source"),
#     ("enable", "Software update", "target"),
#     ("FOP 1", "Enable", "exchanges"),
#     ("Enable", "Get Software-update", "source"),
#     ("Enable", "Improve motor performance", "target"),
#     ("FOP 1", "Approval", "exchanges"),
#     ("Approval", "Get Software-update", "source"),
#     ("Approval", "connected to the center", "target"),
#     ("Get Software-update", "FOP 2", "port"),
#     ("FOP 2", "Monitor operation", "exchanges"),
#     ("Monitor operation", "Get Software-update", "source"),
#     ("Monitor operation", "Obtain car racing experience", "target"),
#     ("Obtain car racing experience", "Driver", "allocated to"),
#     ("Obtain car racing experience", "FIP 1", "port"),
#     ("FIP 1", "Experience", "exchanges"),
#     ("Experience", "Sporty drive", "source"),
#     ("Experience", "Obtain car racing experience", "target"),
#     ("FIP 1", "Experience", "exchanges"),
#     ("Experience", "Sporty drive", "source"),
#     ("Experience", "Obtain car racing experience", "target"),
#     ("Obtain car racing experience", "FIP 2", "port"),
#     ("FIP 2", "Monitor operation", "exchanges"),
#     ("Monitor operation", "Get Software-update", "source"),
#     ("Monitor operation", "Obtain car racing experience", "target"),
#     ("Drive vehicle", "Driver", "allocated to"),
#     ("Drive vehicle", "inTerrain", "port"),
#     ("inTerrain", "Terrain", "exchanges"),
#     ("Terrain", "Provide diverse terrain", "source"),
#     ("Terrain", "Drive vehicle", "target"),
#     ("Drive vehicle", "inObjects", "port"),
#     ("inObjects", "Objects", "exchanges"),
#     ("Objects", "Move objects", "source"),
#     ("Objects", "Drive vehicle", "target"),
#     ("Drive vehicle", "FOP 1", "port"),
#     ("FOP 1", "Steering angle", "exchanges"),
#     ("Steering angle", "Drive vehicle", "source"),
#     ("Steering angle", "Steer Wheels", "target"),
#     ("Drive vehicle", "FOP 3", "port"),
#     ("FOP 3", "Accel/Decel", "exchanges"),
#     ("Accel/Decel", "Drive vehicle", "source"),
#     ("Accel/Decel", "Maintain speed", "target"),
#     ("Drive vehicle", "outLocation", "port"),
#     ("outLocation", "Location", "exchanges"),
#     ("Location", "Drive vehicle", "source"),
#     ("Location", "Provide diverse terrain", "target"),
#     ("Drive vehicle", "FOP 5", "port"),
#     ("FOP 5", "Stering", "exchanges"),
#     ("Stering", "Drive vehicle", "source"),
#     ("Stering", "Automatic Steer", "target"),
#     ("Drive vehicle", "FOP 6", "port"),
#     ("FOP 6", "Slow Vehicle", "exchanges"),
#     ("Slow Vehicle", "Drive vehicle", "source"),
#     ("Slow Vehicle", "Apply Brake", "target"),
#     ("Recieve feedback", "Driver", "allocated to"),
#     ("Recieve feedback", "FIP 1", "port"),
#     ("FIP 1", "Information", "exchanges"),
#     ("Information", "Report issues", "source"),
#     ("Information", "Recieve feedback", "target"),
#     ("Recieve feedback", "outSolve", "port"),
#     ("outSolve", "Solve", "exchanges"),
#     ("Solve", "Recieve feedback", "source"),
#     ("Solve", "Provide solution", "target"),
#     ("Provide solution", "Driver", "allocated to"),
#     ("Provide solution", "inSolve", "port"),
#     ("inSolve", "Solve", "exchanges"),
#     ("Solve", "Recieve feedback", "source"),
#     ("Solve", "Provide solution", "target"),
#     ("Provide solution", "outUpdate", "port"),
#     ("outUpdate", "Update", "exchanges"),
#     ("Update", "Provide solution", "source"),
#     ("Update", "Informed Software update", "target"),
#     ("Provide solution", "FOP 2", "port"),
#     ("FOP 2", "provide", "exchanges"),
#     ("provide", "Provide solution", "source"),
#     ("provide", "Get Software-update", "target"),
#     ("Wheel", "Deliver traction to surface", "components"),
#     ("Wheel", "Steer Wheels", "components"),
#     ("Wheel", "Wheel In", "port"),
#     ("Wheel In", "M-W1", "exchanges"),
#     ("M-W1", "Wheel Braking Subsystem", "source"),
#     ("M-W1", "Wheel", "target"),
#     ("Wheel", "Wheel Out", "port"),
#     ("Wheel Out", "M-T", "exchanges"),
#     ("M-T", "Wheel", "source"),
#     ("M-T", "Terrain/Roads", "target"),
#     ("Wheel", "Axle In", "port"),
#     ("Axle In", "C 12", "exchanges"),
#     ("C 12", "Axles", "source"),
#     ("C 12", "Wheel", "target"),
#     ("Wheel", "AE In", "port"),
#     ("AE In", "AE", "exchanges"),
#     ("AE", "Environment", "source"),
#     ("AE", "Wheel", "target"),
#     ("Wheel", "Steer In", "port"),
#     ("Wheel", "Mass", "applied property value groups"),
#     ("Mass", "Unit", "property values"),
#     ("Mass", "Max", "property values"),
#     ("Wheel", "Mass", "applied property value groups"),
#     ("Mass", "Unit", "property values"),
#     ("Mass", "Max", "property values"),
#     ("Initial", "Not Depressed", "outgoing transition"),
#     ("Brake", "Not Depressed", "incoming transition"),
#     ("Brake", "Depressed", "outgoing transition"),
#     ("Unit", "Kg", "exchanges"),
#     ("Unit", "Inches", "exchanges"),
#     ("Initial", "Not Depressed", "outgoing transition"),
#     ("Brake", "Depressed", "incoming transition"),
#     ("Brake", "Not Depressed", "outgoing transition"),
#     ("Unit", "Kg", "exchanges"),
#     ("Unit", "Inches", "exchanges"),
#     ("Initial", "Not Depressed", "outgoing transition"),
#     ("Brake", "Depressed", "incoming transition"),
#     ("Brake", "Not Depressed", "outgoing transition")
# ]
# ```
# graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 💬 Predefined Prompts for Analysis
#
# ### Purpose
# This cell contains predefined prompts for analyzing different types of ARCADIA elements, including components, functions, operational processes, and a default prompt. You can use these as-is or tailor them to suit your specific needs.
#
#
# ### Instructions
# 1. The appropriate prompt will be used for your analysis needs.
# 2. Modify the prompt to include additional details or requirements, if necessary.
#
# ### Notes
# - Predefined prompts are designed to guide analysis and ensure consistency.
# - Tailoring the prompts allows you to focus on specific aspects of the model relevant to your use case.
#
# > 💡 **Tip:** Save your tailored prompts for reuse in similar analyses or workflows.

# %%
component_prompt = """
Please analyze the yaml file and display the result as .html and specifically provide insights on:
1. The purpose of the component.
2. Any components that make it up.
3. A list of allocated functions and their potential roles.
4. How the ports relate to the functions.
5. Any traceabilty artifacts linked to the component and the artifacts url.
6. Suggestions for improving the component description.
7. Create a tabular table with columns for the component and its ports and the port interfaces, the interface souce and the interface target.
8. List any property values and the related model element.
9. A summary of any related state machines.
"""
function_prompt = """
Please analyze the yaml file and display the result as .html specifically provide insights on:
1. The purpose of the function.
2. Its owning component.
4. Any ports relate to the functions.
5. Any traceabilty artifacts linked to the component and the artifacts url.
6. Suggestions for improving the function description.
7. Create a tabular table with columns for the owning component, this function, its ports and the functional exchanges.
"""
activity_prompt = """
Please analyze the yaml file and display the result as .html specifically provide insights on:
1. The purpose of the activity.
2. Its actor or entiry.
4. Any traceabilty artifacts linked to the component and the artifacts url.
7. Suggestions for improving the activity description.
7. Create a tabular table with columns for the owning entity or actor, this activity, its exchanges.
"""
functional_chain_prompt = """
Please analyze the YAML file and display the result as .html specifically provide insights on:
1. The purpose of the functional chain.
2. A table with first column being the owning component, the second being a function, last column being involved functional exchange, organized by involved functional exchanges.
3. Any traceabilty artifacts linked to functional chain, functions, owning component and the traceability artifacts url.
4. List any property values and the related model element.
Please format the analysis in .html suitable for Juypter Notbook display operation.
"""
operational_process_prompt = """
Please analyze the YAML file and display the result as .html specifically provide insights on:
1. The purpose of the operation process.
2. A table with first column being the owning component, the second being a activities, last column being involved activity exchange, organized by involved activity exchanges.
3. Any traceabilty artifacts linked to the operational process chain, activities, owning component and the traceability artifacts url.
4. List any property values and the related model element.
Please format the analysis in .html suitable for Juypter Notbook display operation.
"""
diagram_prompt = """
Please analyze the YAML file and display the result as .html specifically provide insights on:
1. The purpose of the diagram based on its related nodes.
2. Describe what the nodes represent in the ARCADIA method and what the diagram is describing.
Please format the analysis in .html suitable for Juypter Notbook display operation.
"""
default_prompt = """
Please analyze the YAML file and display the result as .html specifically provide insights on:
1. The purpose of the primary component listed first in the yaml file.=.
2. List any property values and the related model element.
Please format the analysis in .html suitable for Juypter Notbook display operation.
"""

# %% [markdown]
# ## ⚙️ Execute Default Prompts
#
# ### Purpose
# This cell executes the **default prompts** defined for analyzing the model. These prompts are designed to provide general insights and overviews when specific object types or contexts are not explicitly defined.
#
# ### What This Cell Does
# - Reads the structured input file (e.g., `capella_model.yaml`).
# - Uses the default prompts to query key details about the selected object(s).
# - Outputs the results directly in the notebook.
#
# ### 🛠️ Instructions
# 1. Ensure the `capella_model.yaml` file is generated and up-to-date.
# 2. Run this cell to execute the default prompts.
# 3. Review the output to verify the accuracy and relevance of the analysis.
#
# ### 📝 Notes
# - The default prompts are **general-purpose** and may not capture all details specific to certain object types.
# - For more tailored analysis, consider using prompts designed for specific ARCADIA elements.
#
# > 💡 **Tip:** Use the default prompts as a starting point, then refine or modify them based on your analysis needs.

# %%
import os
from openai import OpenAI
from IPython.core.display import HTML
from IPython.display import display, clear_output, Markdown
#from capella_tools  import Open_AI_RAG_manager

from capella_tools import Open_AI_RAG_manager
#print(object)
if object["type"] ==  "LogicalComponent" or object["type"] ==  "SystemComponent" or object["type"] ==  "PhysicalComponent-BEHAVIOR"  or object["type"] ==  "PhysicalComponent-NODE" :
    prompt = component_prompt
elif object["type"] ==  "FunctionalChain" :  
    prompt = functional_chain_prompt
elif object["type"] ==  "OperationalProcess":  
    prompt = functional_chain_prompt
elif object["type"] ==  "SystemFuntion" or object["type"] ==  "LogicalFunction" or object["type"] ==  "PhysicalFunction":
    prompt = function_prompt
elif object["type"] ==  "OperationalActivity" : 
    prompt = activity_prompt
elif object["type"] ==  "Diagram" : 
    prompt = diagram_prompt
else :
    prompt = default_prompt    
# Display Prompt
display(Markdown(f"# The architecture is analyzed by ChatGPT with following prompt.\n {prompt}\n"))


analyzer.initial_prompt(prompt)
chatgpt_response = analyzer.get_response()
# Out:
# # The architecture is analyzed by ChatGPT with following prompt.
#
# Please analyze the YAML file and display the result as .html specifically provide insights on:
# 1. The purpose of the functional chain.
# 2. A table with first column being the owning component, the second being a function, last column being involved functional exchange, organized by involved functional exchanges.
# 3. Any traceabilty artifacts linked to functional chain, functions, owning component and the traceability artifacts url.
# 4. List any property values and the related model element.
# Please format the analysis in .html suitable for Juypter Notbook display operation.
# **ChatGPT Analysis:**
# ```html
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Analysis of YAML Content</title>
#
# </head>
# <body>
# <h1>YAML Content Analysis</h1>
# <h2>1. Purpose of the Functional Chain: "Manual Braking"</h2>
# <p>The "Manual Braking" functional chain represents the sequence of actions involved in the braking process of a vehicle. It encompasses a set of logical functions and functional exchanges to ensure the proper application of brakes, conversion of mechanical force to hydraulic force, and ultimately stopping the vehicle safely.</p>
# <h2>2. Table of Components, Functions, and Functional Exchanges</h2>
# <table>
# <tr>
# <th>Owning Component</th>
# <th>Function</th>
# <th>Involved Functional Exchange</th>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Apply Brake</td>
# <td>Brake Force</td>
# </tr>
# <tr>
# <td>Brake pedal</td>
# <td>Brake</td>
# <td>Brake force</td>
# </tr>
# <tr>
# <td>Brake Master Cylinder</td>
# <td>Converts mechanical to hydaulic</td>
# <td>Low Pressure</td>
# </tr>
# <tr>
# <td>Hydraulic Control Modulator</td>
# <td>Amplify force</td>
# <td>High Pressure</td>
# </tr>
# <tr>
# <td>Brake Lines and Fluid</td>
# <td>Distribute force</td>
# <td>Pad Force 1</td>
# </tr>
# <tr>
# <td>ABS Controller</td>
# <td>Reduce Skid</td>
# <td>Modulate Brake</td>
# </tr>
# <tr>
# <td>Terrain/Roads</td>
# <td>Provide Friction</td>
# <td>Traction 1</td>
# </tr>
# <tr>
# <td>Wheel</td>
# <td>Deliver traction to surface</td>
# <td>Traction 2</td>
# </tr>
# </table>
# <h2>3. Traceability Artifacts</h2>
# <ul>
# <li>Braking Torque:
#         <ul>
# <li>Linked to Function: Brake 1</li>
# <li>URL: <a href="https://polarion.diswx.com/polarion/oslc/services/projects/drivepilot/workitems/DP-1318">https://polarion.diswx.com/polarion/oslc/services/projects/drivepilot/workitems/DP-1318</a></li>
# </ul>
# </li>
# <li>Pedal Force Feedback:
#         <ul>
# <li>Linked to Functional Exchange: Brake Force</li>
# <li>URL: <a href="https://polarion.diswx.com/polarion/oslc/services/projects/drivepilot/workitems/DP-1319">https://polarion.diswx.com/polarion/oslc/services/projects/drivepilot/workitems/DP-1319</a></li>
# </ul>
# </li>
# </ul>
# <h2>4. Property Values and Related Model Elements</h2>
# <ul>
# <li>Wheel:
#         <ul>
# <li>Mass:
#                 <ul>
# <li>Unit: Kg</li>
# <li>Max: 25.0</li>
# </ul>
# </li>
# </ul>
# </li>
# <li>Brake Master Cylinder:
#         <ul>
# <li>Bore Size:
#                 <ul>
# <li>Units: Inches</li>
# <li>Max: 1.0</li>
# <li>Min: 0.625</li>
# </ul>
# </li>
# </ul>
# </li>
# <li>Hydraulic Control Modulator:
#         <ul>
# <li>Transmission Period:
#                 <ul>
# <li>Units: msec</li>
# <li>Max: 10.0</li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </body>
# </html>
# ```

# %% [markdown]
# ## ⚙️ Execute Followup Prompts
#
# ### Purpose
# This cell executes the **follow up prompts** defined for analyzing the model. These prompts can be added by the note book user in addition to the default prompts
#
# ### What This Cell Does
# - Use the structured input file (e.g., `capella_model.yaml`).
# - Excutes the prompt defined in the cell.
# - Outputs the results directly in the notebook.
#
# ### 🛠️ Instructions
# 1. Ensure the `capella_model.yaml` file is generated and up-to-date.
# 2. Run this cell to execute the default prompts.
# 3. Review the output to verify the accuracy and relevance of the analysis.
#
# > 💡 **Tip:** Modify the promt to your needs.

# %%
analyzer.follow_up_prompt("List the functions of the component")
chatgpt_response = analyzer.get_response()

# Step 3: Display the response in the notebook
#print("ChatGPT Analysis:\n")
display(Markdown(f"\n\n**ChatGPT Analysis:**\n"))
#print(chatgpt_response)
display(HTML(chatgpt_response))
# Out:
# **ChatGPT Analysis:**
# ```html
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Component Function List</title>
#
# </head>
# <body>
# <h1>Functions by Component</h1>
# <table>
# <tr>
# <th>Owning Component</th>
# <th>Function</th>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Apply Brake</td>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Drive on a race track</td>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Car racing experience absorbed</td>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Report issues</td>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Get informed with issues</td>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Get Software-update</td>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Obtain car racing experience</td>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Drive vehicle</td>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Recieve feedback</td>
# </tr>
# <tr>
# <td>Driver</td>
# <td>Provide solution</td>
# </tr>
# <tr>
# <td>Brake pedal</td>
# <td>Brake</td>
# </tr>
# <tr>
# <td>Brake Master Cylinder</td>
# <td>Converts mechanical to hydaulic</td>
# </tr>
# <tr>
# <td>Brake Master Cylinder</td>
# <td>Detect Level</td>
# </tr>
# <tr>
# <td>ABS Controller</td>
# <td>Reduce Skid</td>
# </tr>
# <tr>
# <td>Terrain/Roads</td>
# <td>Provide Friction</td>
# </tr>
# <tr>
# <td>Terrain/Roads</td>
# <td>Provide diverse terrain</td>
# </tr>
# <tr>
# <td>Terrain/Roads</td>
# <td>Provide road markers</td>
# </tr>
# <tr>
# <td>Hydraulic Control Modulator</td>
# <td>Amplify force</td>
# </tr>
# <tr>
# <td>Brake Lines and Fluid</td>
# <td>Distribute force</td>
# </tr>
# <tr>
# <td>Wheel</td>
# <td>Deliver traction to surface</td>
# </tr>
# <tr>
# <td>Wheel</td>
# <td>Steer Wheels</td>
# </tr>
# <tr>
# <td>Wheel</td>
# <td>Steer Wheels</td>
# </tr>
# </table>
# </body>
# </html>
# ```

# %% [markdown]
# ## 💬 Launch Interactive Chat on Structured Input
#
# ### Purpose
# This cell launches an interactive chat session based on the structured input file, leveraging ARCADIA and Polarion terminology to ensure the analysis remains consistent with the modeling context.
#
# ### Key Features
# - Uses the generated structured input file (e.g., `capella_model.yaml`) to guide the conversation.
# - Supports ARCADIA terms such as **functions**, **components**, **activities**, and **exchanges**.
# - Incorporates Polarion terms like **workitem**, **requirement**, and **traceability** for seamless integration with requirements management workflows.
#
# ### How It Works
# 1. The structured input file provides context for the chat session.
# 2. You can interactively query details about the model elements, relationships, and dependencies.
# 3. Responses are tailored using ARCADIA and Polarion terminology.
#
# ### Example Prompts
# - **For ARCADIA:**
#   ```plaintext
#   What are the dependencies and exchanges for the selected function in the Logical Architecture phase?
#
# - **For Polarion:**
#   ```plaintext
#   Provide the traceability matrix for the workitem linked to this component.
#   ```
# ### 🛠️ Instructions
# 1. Ensure the `capella_model.yaml` file has been generated and is up-to-date.
# 2. Run this cell to start the interactive chat session.
# 3. Enter your queries using **ARCADIA** or **Polarion** terms for accurate and relevant responses.
#
# ### 📝 Notes
# - The interactive chat dynamically adapts to the content in the structured input file.
# - Use precise and contextual queries to ensure the best results and insights.
#
# > 💡 **Tip:** If you're unfamiliar with ARCADIA or Polarion terminology, consult the respective documentation or glossary for guidance.

# %%
analyzer.interactive_chat()
# Out:
# Starting interactive chat...
# Output()
# Textarea(value='', layout=Layout(border_bottom='2px solid #4A90E2', border_left='2px solid #4A90E2', border_ri…
# HBox(children=(Button(button_style='primary', description='Execute', style=ButtonStyle()), Button(button_style…
# Dropdown(description='Load file:', layout=Layout(width='auto'), options=('', 'embeddings.json', 'capella_model…
# Waiting for chat interactions...

# %%
print("Done")
# Out:
# Done

# %% [markdown]
# #
